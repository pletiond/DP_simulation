# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
df_TP = pd.read_csv('../tests/06/in_Central_out_TP.csv', delimiter=';')
tp = df_TP['car_id'].value_counts().sort_index()

df_TPTS = pd.read_csv('../tests/06/in_Central_out_TPTS.csv', delimiter=';')
tpts = df_TPTS['car_id'].value_counts().sort_index()

df_central = pd.read_csv('../tests/06/in2_Central.csv', delimiter=';')
central = df_central['car_id'].value_counts().sort_index()

# %%
df_central['car_id'].count()
# Out:
# 907

# %%
display(tp.describe())
sns.countplot(df_TP['car_id'])
# Out:
# count    20.000000
# mean     45.350000
# std       1.785173
# min      41.000000
# 25%      44.000000
# 50%      45.000000
# 75%      46.000000
# max      49.000000
# Name: car_id, dtype: float64

# %%
display(tpts.describe())
sns.countplot(df_TPTS['car_id'])
# Out:
# count    20.000000
# mean     45.350000
# std       2.207046
# min      41.000000
# 25%      43.750000
# 50%      46.000000
# 75%      47.000000
# max      49.000000
# Name: car_id, dtype: float64

# %%
display(central.describe())
sns.countplot(df_central['car_id'])
# Out:
# count    20.00000
# mean     45.35000
# std       2.83354
# min      41.00000
# 25%      43.75000
# 50%      45.00000
# 75%      47.25000
# max      51.00000
# Name: car_id, dtype: float64

# %%
df_central['car_id'].value_counts()
# Out:
# 17    51
# 25    50
# 19    49
# 16    48
# 29    48
# 22    47
# 20    46
# 13    46
# 11    46
# 15    45
# 10    45
# 23    44
# 18    44
# 27    44
# 12    44
# 28    43
# 14    43
# 21    42
# 24    41
# 26    41
# Name: car_id, dtype: int64

# %%
tp
# Out:
# 10    44
# 11    45
# 12    49
# 13    45
# 14    45
# 15    48
# 16    46
# 17    44
# 18    44
# 19    46
# 20    46
# 21    41
# 22    44
# 23    47
# 24    46
# 25    45
# 26    48
# 27    45
# 28    44
# 29    45
# Name: car_id, dtype: int64
