# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
#50
index = [5,10,15,20,25,30, 35]
df = pd.DataFrame(index=index)
df['TP']   = [155, 250, 360, 460, 505, 525, 525]
df['TPTS'] = [170, 350, 460, 630, 660, 750, 950]
df['LCPD'] = [160, 295, 445, 595, 690, 855, None]

ax = df.plot()
ax.xaxis.set_ticks(np.arange(5, 40, 5))
ax.yaxis.set_ticks(np.arange(0, 1100, 100))

# %%
#Static
index = [5,10,15,20,25,30,35, 40, 45, 50, 55, 60, 65, 70, 80, 90, 100]
df = pd.DataFrame(index=index)
df['TP']   = [165, 270, 270, 430, 520, 370, 385, 340,  615,  205,  590,  340,  475,  340,   485,  585, 435]
df['TPTS'] = [160, 345, 385, 650, 730, 761, 955, 1115, 1170, 1285, 1150, 1295, 1435, 1355,  1300, 1325, 1420]
df['LCPD'] = [165, 295, 380, 520, 675, 875, 975, None, None, None, None, None, None, None, None, None, None]

ax = df.plot()
ax.xaxis.set_ticks(np.arange(0, 110, 10))
ax.yaxis.set_ticks(np.arange(0, 1500, 200))
ax.set(xlabel='Počet vozidel', ylabel='Doba do kolapsu systému')
ax.get_figure().savefig(f't00.png', dpi=300)

# %%
#Static Tasks
index = [5,10,15,20,25,30,35, 40, 45, 50, 55, 60, 65, 70, 80, 90, 100]
df = pd.DataFrame(index=index)
df['TP']   = [30, 81,  85,  202, 295, 156, 172, 134,  407,  160,  380,  145,  253,  155,   264,  456, 259]
df['TPTS'] = [27, 125, 162, 435, 601, 860, 947, 1284, 1417, 1706, 1388, 1743, 2116, 1897,  1750, 1817, 2082]
df['LCPD'] = [31, 101, 162, 298, 496, 840, 1001, None, None, None, None, None, None, None, None, None, None]

ax = df.plot()
ax.xaxis.set_ticks(np.arange(0, 110, 10))
ax.yaxis.set_ticks(np.arange(0, 2300, 200))
ax.set(xlabel='Počet vozidel', ylabel='Počet splněných úkolů do kolapsu')
ax.get_figure().savefig(f't00_tasks.png', dpi=300)

# %%
ax= df.plot()
ax.set(xlabel='Čas', ylabel='Průměrný čas do vyzvednutí úkolu')
ax.get_figure().savefig(f't07.png', dpi=300)

# %%
521.0161662817552 / 7.447300771208226
# Out:
# 69.9604034116682

# %%
#Static
index = [5,10,15,20,25,30,35, 40, 45, 50, 55, 60, 65, 70, 80, 90, 100]
df = pd.DataFrame(index=index)
df['TP']   = [165, 270, 270, 430, 520, 370, 385, 340,  615,  205,  590,  340,  475,  340,   485,  585, 435]
df['TPTS'] = [185, 315, 420, 590, 720, 795, 970, 1115, 1170, 1285, 1150, 1295, 1435, 1355,  1300, 1325, 1420]
df['LCPD'] = [165, 295, 380, 520, 675, 875, 945, None, None, None, None, None, None, None, None, None, None]

ax = df.plot()
ax.xaxis.set_ticks(np.arange(0, 110, 10))
ax.yaxis.set_ticks(np.arange(0, 1500, 200))
ax.set(xlabel='Počet vozidel', ylabel='Doba do kolapsu systému')
ax.get_figure().savefig(f't00.png', dpi=300)
