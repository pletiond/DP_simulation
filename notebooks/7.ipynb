# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
dummy = pd.read_csv('../tests/08/LCPD20-dummy.csv', header = None)
prob = pd.read_csv('../tests/08/LCPD20-prob.csv', header = None)
df = pd.DataFrame()
df['Nejbližší'] = dummy[0]
df['Nejpravděpodobnější'] = prob[0]

# %%
ax= df.plot()
ax.set(xlabel='Čas', ylabel='Průměrný čas do vyzvednutí úkolu')
ax.get_figure().savefig(f't07.png', dpi=300)

# %%
521.0161662817552 / 7.447300771208226
# Out:
# 69.9604034116682
